# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = np.array([
[120,20,9],[40,60,14],[200,10,18],
[80,35,12],[150,15,19],[30,70,10]
])

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data)

print("Cluster Labels:", kmeans.labels_)
print("Centroids:\n", kmeans.cluster_centers_)

plt.scatter(data[:,0], data[:,1], c=kmeans.labels_, cmap='viridis', s=100)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], marker='X', s=200)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering")
plt.show()
# Out:
# Cluster Labels: [2 1 0 2 2 1]
# Centroids:
#  [[200.          10.          18.        ]
#  [ 35.          65.          12.        ]
#  [116.66666667  23.33333333  13.33333333]]
